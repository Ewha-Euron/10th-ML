# %% [markdown]
# # Insurance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/0315j/OneDrive/바탕 화면/새 폴더/Euron/data/insurance.csv")

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.isnull().sum().sort_values(ascending= False)
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.displot(df['age'])
plt.title('Age distribution')
plt.ylabel('density')
plt.xlabel('age')
plt.show()

# %%
sns.displot(df['charges'])
plt.title('charges distribution')
plt.ylabel('density')
plt.xlabel('charges')
plt.show()

# %%
sns.displot(df['bmi'])
plt.title('bmi distribution')
plt.ylabel('density')
plt.xlabel('bmi')
plt.show()

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize = (6,4))
sns.countplot(df['region'])
plt.title('region distribution')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize = (6,4))
sns.countplot(df['sex'])
plt.title('sex distribution')
plt.show()

# %%
df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize = (6,4))
sns.countplot(df['children'])
plt.title('children distribution')
plt.show()

# %%
df['sex'] = pd.factorize(df['sex'])[0] + 1
df['region'] = pd.factorize(df['region'])[0] + 1
df['smoker'] = pd.factorize(df['smoker'])[0] + 1
corr = df.corr()
corr['charges'].sort_values(ascending=False)
# Out:
# charges     1.000000
# age         0.299008
# bmi         0.198341
# children    0.067998
# sex         0.057292
# region      0.006208
# smoker     -0.787251
# Name: charges, dtype: float64

# %%
fig = plt.figure(figsize = (6, 4))
data_ploting = df.corr(method= 'pearson')
sns.heatmap(data_ploting, cmap='Reds', linecolor='black', linewidths= 2 )
plt.show()

# %%
fig = plt.figure(figsize = (6, 4))
sns.pairplot(df,diag_kind='kde');

# %%
X = df.drop('charges', axis = 1)
y = df['charges']
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler= StandardScaler()
scaler.fit(X_train)
X_train_scaled= scaler.transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %% [markdown]
# linear_reg_model= LinearRegression()
# linear_reg_model.fit(X_train_scaled, y_train)

# %%
y_pred = linear_reg_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_li_reg= metrics.mean_absolute_error(y_test, y_pred)
MSE_li_reg = metrics.mean_squared_error(y_test, y_pred)
RMSE_li_reg =np.sqrt(MSE_li_reg)
pd.DataFrame([MAE_li_reg, MSE_li_reg, RMSE_li_reg], index=['MAE_li_reg', 'MSE_li_reg', 'RMSE_li_reg'], columns=['Metrics'])
# Out:
#                   Metrics
# MAE_li_reg   3.990250e+03
# MSE_li_reg   3.353013e+07
# RMSE_li_reg  5.790521e+03

# %%
scores = cross_val_score(linear_reg_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.88791389 0.85653048 0.84404195 0.87198372 0.84417492]

# %%
r2_score(y_test, linear_reg_model.predict(X_test_scaled))
# Out:
# 0.7613126015198817

# %% [markdown]
# Gradient_model = GradientBoostingRegressor()
# Gradient_model.fit(X_train_scaled, y_train)

# %%
y_pred = Gradient_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_gradient= metrics.mean_absolute_error(y_test, y_pred)
MSE_gradient = metrics.mean_squared_error(y_test, y_pred)
RMSE_gradient =np.sqrt(MSE_gradient)
pd.DataFrame([MAE_gradient, MSE_gradient, RMSE_gradient], index=['MAE_gradient', 'MSE_gradient', 'RMSE_gradient'], columns=['Metrics'])
# Out:
#                     Metrics
# MAE_gradient   2.528851e+03
# MSE_gradient   2.110725e+07
# RMSE_gradient  4.594262e+03

# %%
scores = cross_val_score(Gradient_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.94582994 0.9144513  0.91687262 0.92481108 0.91716787]

# %%
r2_score(y_test, Gradient_model.predict(X_test_scaled))
# Out:
# 0.849746079970233

# %%
XGB_model =XGBRegressor()
XGB_model.fit(X_train_scaled, y_train);

# %%
y_pred = XGB_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_XGB= metrics.mean_absolute_error(y_test, y_pred)
MSE_XGB = metrics.mean_squared_error(y_test, y_pred)
RMSE_XGB =np.sqrt(MSE_XGB)
pd.DataFrame([MAE_XGB, MSE_XGB, RMSE_XGB], index=['MAE_XGB', 'MSE_XGB', 'RMSE_XGB'], columns=['Metrics'])
# Out:
#                Metrics
# MAE_XGB   3.142590e+03
# MSE_XGB   2.976529e+07
# RMSE_XGB  5.455757e+03

# %%
scores = cross_val_score(XGB_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.91782241 0.88730325 0.90410079 0.90440364 0.88383429]

# %%
r2_score(y_test, XGB_model.predict(X_test_scaled))
# Out:
# 0.7881129907007072

# %%
tree_reg_model =DecisionTreeRegressor()
tree_reg_model.fit(X_train_scaled, y_train);

# %%
y_pred = tree_reg_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_tree_reg= metrics.mean_absolute_error(y_test, y_pred)
MSE_tree_reg = metrics.mean_squared_error(y_test, y_pred)
RMSE_tree_reg =np.sqrt(MSE_tree_reg)
pd.DataFrame([MAE_tree_reg, MSE_tree_reg, RMSE_tree_reg], index=['MAE_tree_reg', 'MSE_tree_reg', 'RMSE_tree_reg'], columns=['Metrics'])
# Out:
#                     Metrics
# MAE_tree_reg   3.543507e+03
# MSE_tree_reg   5.128061e+07
# RMSE_tree_reg  7.161048e+03

# %%
scores = cross_val_score(tree_reg_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.82886377 0.81884094 0.83692076 0.87677546 0.85518786]

# %%
r2_score(y_test, tree_reg_model.predict(X_test_scaled))
# Out:
# 0.6349541234396772

# %%
forest_reg_model =RandomForestRegressor()
forest_reg_model.fit(X_train_scaled, y_train);

# %%
y_pred = forest_reg_model.predict(X_test_scaled)
y_pred = pd.DataFrame(y_pred)
MAE_forest_reg= metrics.mean_absolute_error(y_test, y_pred)
MSE_forest_reg = metrics.mean_squared_error(y_test, y_pred)
RMSE_forest_reg =np.sqrt(MSE_forest_reg)
pd.DataFrame([MAE_forest_reg, MSE_forest_reg, RMSE_forest_reg], index=['MAE_forest_reg', 'MSE_forest_reg', 'RMSE_forest_reg'], columns=['Metrics'])
# Out:
#                       Metrics
# MAE_forest_reg   2.924089e+03
# MSE_forest_reg   2.543724e+07
# RMSE_forest_reg  5.043535e+03

# %%
scores = cross_val_score(forest_reg_model, X_train_scaled, y_train, cv=5)
print(np.sqrt(scores))
# Out:
# [0.94086164 0.90190866 0.92192061 0.91416538 0.9034794 ]

# %%
r2_score(y_test, forest_reg_model.predict(X_test_scaled))
# Out:
# 0.8189225879977886

# %% [markdown]
# # Avocado

# %%
# !pip install pycaret
# !pip install markupsafe==2.0.1
# !pip jinja2
# Out:
# Requirement already satisfied: pycaret in c:\users\0315j\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (8.27.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (7.8.1)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (4.66.5)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.3.0)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.3.2)
# Requirement already satisfied: numba>=0.55.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (7.0.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.7.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.3.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.14.2)
# Requirement already satisfied: sktime==0.26.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\0315j\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (24.1)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\0315j\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\0315j\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\0315j\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.17.0)
# Requirement already satisfied: decorator in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: colorama in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: choreographer>=1.3.0 in c:\users\0315j\anaconda3\lib\site-packages (from kaleido>=0.2.1->pycaret) (1.3.0)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\0315j\anaconda3\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\0315j\anaconda3\lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.9)
# Requirement already satisfied: wheel in c:\users\0315j\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.44.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\0315j\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\0315j\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\0315j\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\0315j\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\0315j\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\0315j\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.3)
# Requirement already satisfied: dash>=2.11.0 in c:\users\0315j\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (4.1.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\0315j\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.4)
# Requirement already satisfied: urllib3 in c:\users\0315j\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\0315j\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\0315j\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\0315j\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\0315j\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2026.2.25)
# Requirement already satisfied: platformdirs>=4.3.6 in c:\users\0315j\anaconda3\lib\site-packages (from choreographer>=1.3.0->kaleido>=0.2.1->pycaret) (4.9.6)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\0315j\anaconda3\lib\site-packages (from choreographer>=1.3.0->kaleido>=0.2.1->pycaret) (4.1.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.11.0)
# Requirement already satisfied: retrying in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\0315j\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.10.6)
# Requirement already satisfied: pywin32>=300 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: six in c:\users\0315j\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\0315j\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\0315j\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (7.2.2)
# Requirement already satisfied: executing in c:\users\0315j\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\0315j\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\0315j\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\0315j\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\0315j\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (6.4.1)
# Collecting markupsafe>=2.0.1 (from pycaret)
#   Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (7.16.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.9.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\0315j\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\0315j\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\0315j\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\0315j\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\0315j\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.6.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: webencodings in c:\users\0315j\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.1)
# Requirement already satisfied: uri-template in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\0315j\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.5)
# Requirement already satisfied: pycparser in c:\users\0315j\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\0315j\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.2.3)
# Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Installing collected packages: markupsafe
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
# Successfully installed markupsafe-3.0.3
# Collecting markupsafe==2.0.1
#   Using cached MarkupSafe-2.0.1-cp312-cp312-win_amd64.whl
# Installing collected packages: markupsafe
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
# Successfully installed markupsafe-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# werkzeug 3.0.3 requires MarkupSafe>=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# ERROR: unknown command "jinja2"

# %%
# pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\0315j\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (8.27.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (7.8.1)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (4.66.5)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.3.0)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.3.2)
# Requirement already satisfied: numba>=0.55.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (7.0.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.7.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.3.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.14.2)
# Requirement already satisfied: sktime==0.26.0 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\0315j\anaconda3\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\0315j\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (24.1)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\0315j\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\0315j\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\0315j\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.17.0)
# Requirement already satisfied: decorator in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: colorama in c:\users\0315j\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: choreographer>=1.3.0 in c:\users\0315j\anaconda3\lib\site-packages (from kaleido>=0.2.1->pycaret) (1.3.0)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\0315j\anaconda3\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\0315j\anaconda3\lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.9)
# Requirement already satisfied: wheel in c:\users\0315j\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.44.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\0315j\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\0315j\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\0315j\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\0315j\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\0315j\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\0315j\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\0315j\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.3)
# Requirement already satisfied: dash>=2.11.0 in c:\users\0315j\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (4.1.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\0315j\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.4)
# Requirement already satisfied: urllib3 in c:\users\0315j\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\0315j\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\0315j\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\0315j\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\0315j\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2026.2.25)
# Requirement already satisfied: platformdirs>=4.3.6 in c:\users\0315j\anaconda3\lib\site-packages (from choreographer>=1.3.0->kaleido>=0.2.1->pycaret) (4.9.6)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\0315j\anaconda3\lib\site-packages (from choreographer>=1.3.0->kaleido>=0.2.1->pycaret) (4.1.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.11.0)
# Requirement already satisfied: retrying in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\0315j\anaconda3\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\0315j\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.10.6)
# Requirement already satisfied: pywin32>=300 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: six in c:\users\0315j\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\0315j\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\0315j\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (7.2.2)
# Requirement already satisfied: executing in c:\users\0315j\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\0315j\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\0315j\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\0315j\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\0315j\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\0315j\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\0315j\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (6.4.1)
# Collecting markupsafe>=2.0.1 (from pycaret)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (7.16.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\0315j\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.9.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\0315j\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\0315j\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\0315j\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\0315j\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\0315j\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.6.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\0315j\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\0315j\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: webencodings in c:\users\0315j\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.1)
# Requirement already satisfied: uri-template in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\0315j\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\0315j\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\0315j\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.5)
# Requirement already satisfied: pycparser in c:\users\0315j\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\0315j\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.5->pycaret) (1.2.3)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Installing collected packages: markupsafe
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
# Successfully installed markupsafe-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy
import pycaret

# %%
# --- Importing Libraries ---
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import pycaret
import warnings
import jinja2

from sklearn.preprocessing import LabelEncoder
from scipy import stats
from scipy.stats import *
from pycaret.regression import *

# --- Libraries Settings ---
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 100

# %%
# --- Create List of Color Palletes ---
olive_grad = ['#2A3F07', '#557F0F', '#7FBE17', '#A4E637', '#C1EE76']
yellow_grad = ['#413D05', '#837A0B', '#C5B710', '#E8DA2E', '#F9EE6A']
color_mix = ['#356211', '#6C8F32', '#F2E880', '#C15C37', '#AA471F']
black_grad = ['#100C07', '#3E3B39', '#6D6A6A', '#9B9A9C', '#CAC9CD']

# --- Plot Color Palletes --
sns.palplot(olive_grad)
sns.palplot(yellow_grad)
sns.palplot(color_mix)
sns.palplot(black_grad)

# %%
# --- Reading Dataset ---
ds = pd.read_csv("C:/Users/0315j/OneDrive/바탕 화면/새 폴더/Euron/data/avocado.csv")
ds.head().style.background_gradient(cmap='Greens').set_properties(**{'font-family': 'Segoe UI'}).hide()
# Out:
# <style type="text/css">
# #T_3e012_row0_col0, #T_3e012_row0_col6, #T_3e012_row0_col9, #T_3e012_row0_col10, #T_3e012_row0_col12, #T_3e012_row1_col4, #T_3e012_row1_col10, #T_3e012_row1_col12, #T_3e012_row2_col2, #T_3e012_row2_col10, #T_3e012_row2_col12, #T_3e012_row3_col7, #T_3e012_row3_col8, #T_3e012_row3_col10, #T_3e012_row3_col12, #T_3e012_row4_col3, #T_3e012_row4_col5, #T_3e012_row4_col10, #T_3e012_row4_col12 {
#   background-color: #f7fcf5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row0_col1, #T_3e012_row0_col11, #T_3e012_row0_col13, #T_3e012_row1_col1, #T_3e012_row1_col11, #T_3e012_row1_col13, #T_3e012_row2_col1, #T_3e012_row2_col11, #T_3e012_row2_col13, #T_3e012_row3_col1, #T_3e012_row3_col11, #T_3e012_row3_col13, #T_3e012_row4_col1, #T_3e012_row4_col11, #T_3e012_row4_col13 {
#   font-family: Segoe UI;
# }
# #T_3e012_row0_col2 {
#   background-color: #005321;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row0_col3 {
#   background-color: #d4eece;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row0_col4 {
#   background-color: #17813d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row0_col5 {
#   background-color: #dcf2d7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row0_col7 {
#   background-color: #1a843f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row0_col8 {
#   background-color: #19833e;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row1_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row1_col2, #T_3e012_row1_col7, #T_3e012_row1_col8, #T_3e012_row2_col3, #T_3e012_row2_col5, #T_3e012_row2_col6, #T_3e012_row3_col4, #T_3e012_row4_col0, #T_3e012_row4_col9 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row1_col3 {
#   background-color: #eff9ec;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row1_col5 {
#   background-color: #f5fbf3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row1_col6 {
#   background-color: #e5f5e1;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row1_col9 {
#   background-color: #f1faee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row2_col0 {
#   background-color: #73c476;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row2_col4 {
#   background-color: #c3e7bc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row2_col7 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row2_col8 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row2_col9, #T_3e012_row4_col7 {
#   background-color: #e9f7e5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row3_col0 {
#   background-color: #228a44;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row3_col2 {
#   background-color: #a7dba0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row3_col3 {
#   background-color: #92d28f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row3_col5 {
#   background-color: #8dd08a;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row3_col6 {
#   background-color: #bae3b3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row3_col9 {
#   background-color: #9cd797;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row4_col2 {
#   background-color: #0b7734;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row4_col4 {
#   background-color: #52b365;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3e012_row4_col6 {
#   background-color: #aedea7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3e012_row4_col8 {
#   background-color: #ebf7e7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_3e012">
#   <thead>
#     <tr>
#       <th id="T_3e012_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_3e012_level0_col1" class="col_heading level0 col1" >Date</th>
#       <th id="T_3e012_level0_col2" class="col_heading level0 col2" >AveragePrice</th>
#       <th id="T_3e012_level0_col3" class="col_heading level0 col3" >Total Volume</th>
#       <th id="T_3e012_level0_col4" class="col_heading level0 col4" >4046</th>
#       <th id="T_3e012_level0_col5" class="col_heading level0 col5" >4225</th>
#       <th id="T_3e012_level0_col6" class="col_heading level0 col6" >4770</th>
#       <th id="T_3e012_level0_col7" class="col_heading level0 col7" >Total Bags</th>
#       <th id="T_3e012_level0_col8" class="col_heading level0 col8" >Small Bags</th>
#       <th id="T_3e012_level0_col9" class="col_heading level0 col9" >Large Bags</th>
#       <th id="T_3e012_level0_col10" class="col_heading level0 col10" >XLarge Bags</th>
#       <th id="T_3e012_level0_col11" class="col_heading level0 col11" >type</th>
#       <th id="T_3e012_level0_col12" class="col_heading level0 col12" >year</th>
#       <th id="T_3e012_level0_col13" class="col_heading level0 col13" >region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3e012_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3e012_row0_col1" class="data row0 col1" >2015-12-27</td>
#       <td id="T_3e012_row0_col2" class="data row0 col2" >1.330000</td>
#       <td id="T_3e012_row0_col3" class="data row0 col3" >64236.620000</td>
#       <td id="T_3e012_row0_col4" class="data row0 col4" >1036.740000</td>
#       <td id="T_3e012_row0_col5" class="data row0 col5" >54454.850000</td>
#       <td id="T_3e012_row0_col6" class="data row0 col6" >48.160000</td>
#       <td id="T_3e012_row0_col7" class="data row0 col7" >8696.870000</td>
#       <td id="T_3e012_row0_col8" class="data row0 col8" >8603.620000</td>
#       <td id="T_3e012_row0_col9" class="data row0 col9" >93.250000</td>
#       <td id="T_3e012_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_3e012_row0_col11" class="data row0 col11" >conventional</td>
#       <td id="T_3e012_row0_col12" class="data row0 col12" >2015</td>
#       <td id="T_3e012_row0_col13" class="data row0 col13" >Albany</td>
#     </tr>
#     <tr>
#       <td id="T_3e012_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_3e012_row1_col1" class="data row1 col1" >2015-12-20</td>
#       <td id="T_3e012_row1_col2" class="data row1 col2" >1.350000</td>
#       <td id="T_3e012_row1_col3" class="data row1 col3" >54876.980000</td>
#       <td id="T_3e012_row1_col4" class="data row1 col4" >674.280000</td>
#       <td id="T_3e012_row1_col5" class="data row1 col5" >44638.810000</td>
#       <td id="T_3e012_row1_col6" class="data row1 col6" >58.330000</td>
#       <td id="T_3e012_row1_col7" class="data row1 col7" >9505.560000</td>
#       <td id="T_3e012_row1_col8" class="data row1 col8" >9408.070000</td>
#       <td id="T_3e012_row1_col9" class="data row1 col9" >97.490000</td>
#       <td id="T_3e012_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_3e012_row1_col11" class="data row1 col11" >conventional</td>
#       <td id="T_3e012_row1_col12" class="data row1 col12" >2015</td>
#       <td id="T_3e012_row1_col13" class="data row1 col13" >Albany</td>
#     </tr>
#     <tr>
#       <td id="T_3e012_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_3e012_row2_col1" class="data row2 col1" >2015-12-13</td>
#       <td id="T_3e012_row2_col2" class="data row2 col2" >0.930000</td>
#       <td id="T_3e012_row2_col3" class="data row2 col3" >118220.220000</td>
#       <td id="T_3e012_row2_col4" class="data row2 col4" >794.700000</td>
#       <td id="T_3e012_row2_col5" class="data row2 col5" >109149.670000</td>
#       <td id="T_3e012_row2_col6" class="data row2 col6" >130.500000</td>
#       <td id="T_3e012_row2_col7" class="data row2 col7" >8145.350000</td>
#       <td id="T_3e012_row2_col8" class="data row2 col8" >8042.210000</td>
#       <td id="T_3e012_row2_col9" class="data row2 col9" >103.140000</td>
#       <td id="T_3e012_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_3e012_row2_col11" class="data row2 col11" >conventional</td>
#       <td id="T_3e012_row2_col12" class="data row2 col12" >2015</td>
#       <td id="T_3e012_row2_col13" class="data row2 col13" >Albany</td>
#     </tr>
#     <tr>
#       <td id="T_3e012_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_3e012_row

# %%
# --- Print Dataset Info ---
print('\033[92m\033[1m'+'.: Imported Dataset Info :.'+'\033[0m')
print('\033[92m*' * 30+'\033[0m')
print('Total Rows:'+'\033[92m\033[1m', ds.shape[0])
print('\033[0m'+'Total Columns:'+'\033[92m\033[1m', ds.shape[1])
print('\033[0m\033[92m'+'*' * 30+'\033[0m')
print('\n')

# --- Print Dataset Detail ---
print('\033[92m\033[1m'+'.: Dataset Details :.'+'\033[0m')
print('\033[0m\033[92m'+'*' * 30+'\033[0m')
ds.info(memory_usage = False)
# Out:
# .: Imported Dataset Info :.
# ******************************
# Total Rows: 18249
# Total Columns: 14
# ******************************
#
#
# .: Dataset Details :.
# ******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)

# %%
# --- Colors and Labels (Null Values Dropped) ---
colors = color_mix[1:3]
labels = ds['type'].dropna().unique()
order = ds['type'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(18, 10))

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Avocado Type Percentage', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', 
          color = black_grad[0])
plt.pie(ds['type'].value_counts(), labels = order, colors = colors, 
        wedgeprops = dict(alpha = 0.8, edgecolor = black_grad[1]), autopct = '%.2f%%')

# --- Bar Chart ---
countplt = plt.subplot(1, 2, 2)
plt.title('Avocado Type Bar Chart', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
ax = sns.countplot(x = 'type', data = ds, palette = colors, order = order, edgecolor = black_grad[2], alpha = 0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, rect.get_height()+0.75,rect.get_height(), horizontalalignment = 'center', 
             fontsize = 11)

plt.xlabel('Types', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Total', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('\033[92m'+'*' * 40)
print('\033[92m\033[1m'+'.: Total Avocado based on each Type :.'+'\033[0m')
print('\033[92m'+'*' * 40+'\033[0m')
ds.type.value_counts(dropna=False)
# Out:
# ****************************************
# .: Total Avocado based on each Type :.
# ****************************************
# type
# conventional    9126
# organic         9123
# Name: count, dtype: int64

# %%
# --- Colors and Labels (Null Values Dropped) ---
colors = sns.color_palette('YlOrBr')
labels = ds['year'].dropna().unique()
order = ds['year'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(18,10))

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Avocado Years Percentage', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
plt.pie(ds['year'].value_counts(), labels = order, colors = colors, 
        wedgeprops = dict(alpha = 0.8, edgecolor = black_grad[1]), autopct = '%.2f%%')

# --- Bar Chart ---
countplt = plt.subplot(1,2,2)
plt.title('Avocado Years Bar Chart', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
ax = sns.countplot(x = 'year', data = ds, palette = colors, order = order, edgecolor = black_grad[2], alpha = 0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, rect.get_height()+0.75,rect.get_height(), horizontalalignment = 'center',
             fontsize = 10)

plt.xlabel('Years', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Total', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('\033[92m'+'*' * 35)
print('\033[92m\033[1m'+'.: Total Avocado based on Year :.'+'\033[0m')
print('\033[92m'+'*' * 35+'\033[0m')
ds.year.value_counts(dropna=False)
# Out:
# ***********************************
# .: Total Avocado based on Year :.
# ***********************************
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
# --- Count Categorical Labels w/Out Dropping Null Walues ---
print('\033[92m'+'*' * 38)
print('\033[92m\033[1m'+'.: Total Avocado based on Regions :.'+'\033[0m')
print('\033[92m'+'*' * 38)
ds.region.value_counts(dropna=False)
# Out:
# **************************************
# .: Total Avocado based on Regions :.
# **************************************
# region
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: count, dtype: int64

# %%
# --- Colors and Labels (Null Values Dropped) ---
colors = olive_grad[0:5]
labels = ds['region'].dropna().unique()
order = ds['region'].value_counts().index

# --- Pie Chart ---
plt.figure(figsize = (15, 15))
plt.title('Regions Percentage', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
plt.pie(ds['region'].value_counts(), labels = order, colors = colors, 
        wedgeprops = dict(alpha = 0.8, edgecolor = black_grad[1]), autopct = '%.2f%%');

# %%
# --- Bar Chart ---
plt.figure(figsize = (15, 15))
plt.title('Regions Bar Chart', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
sns.countplot(y = 'region', data = ds, order = order, palette = colors, edgecolor = black_grad[2], alpha = 0.85)
plt.xlabel('Total', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Regions', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'x', alpha = 0.4);

# %%
# --- Descriptive Statistics ---
ds[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 
    'XLarge Bags']].describe().T.style.background_gradient(cmap='YlOrBr').set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_8edba_row0_col0, #T_8edba_row0_col1, #T_8edba_row0_col2, #T_8edba_row0_col4, #T_8edba_row0_col5, #T_8edba_row0_col6, #T_8edba_row0_col7, #T_8edba_row1_col0, #T_8edba_row2_col0, #T_8edba_row2_col3, #T_8edba_row3_col0, #T_8edba_row3_col3, #T_8edba_row4_col0, #T_8edba_row4_col3, #T_8edba_row4_col4, #T_8edba_row4_col5, #T_8edba_row5_col0, #T_8edba_row5_col3, #T_8edba_row6_col0, #T_8edba_row6_col3, #T_8edba_row7_col0, #T_8edba_row7_col3, #T_8edba_row8_col0, #T_8edba_row8_col1, #T_8edba_row8_col3, #T_8edba_row8_col4, #T_8edba_row8_col5, #T_8edba_row8_col6 {
#   background-color: #ffffe5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row0_col3, #T_8edba_row8_col2 {
#   background-color: #ffffe4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row1_col1, #T_8edba_row1_col2, #T_8edba_row1_col3, #T_8edba_row1_col4, #T_8edba_row1_col5, #T_8edba_row1_col6, #T_8edba_row1_col7 {
#   background-color: #662506;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_8edba_row2_col1, #T_8edba_row3_col1, #T_8edba_row3_col6 {
#   background-color: #fecb5f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row2_col2, #T_8edba_row2_col7 {
#   background-color: #fec754;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row2_col4, #T_8edba_row2_col5 {
#   background-color: #fffacb;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row2_col6, #T_8edba_row5_col6 {
#   background-color: #fee28e;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row3_col2 {
#   background-color: #feca5d;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row3_col4 {
#   background-color: #fedc82;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row3_col5 {
#   background-color: #fede86;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row3_col7 {
#   background-color: #fed069;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row4_col1, #T_8edba_row7_col5 {
#   background-color: #fffddd;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row4_col2 {
#   background-color: #fffddc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row4_col6, #T_8edba_row7_col4 {
#   background-color: #fffee1;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row4_col7 {
#   background-color: #fffcd8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row5_col1 {
#   background-color: #fedb80;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row5_col2 {
#   background-color: #feda7e;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row5_col4 {
#   background-color: #fea332;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row5_col5 {
#   background-color: #fec652;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row5_col7 {
#   background-color: #fed471;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row6_col1, #T_8edba_row6_col7 {
#   background-color: #fee99e;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row6_col2 {
#   background-color: #fee89d;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row6_col4 {
#   background-color: #fee08a;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row6_col5 {
#   background-color: #fee493;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row6_col6 {
#   background-color: #feeca5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row7_col1 {
#   background-color: #fffbd0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row7_col2 {
#   background-color: #ffface;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row7_col6 {
#   background-color: #fffcd4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row7_col7 {
#   background-color: #fff9c7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8edba_row8_col7 {
#   background-color: #fffee2;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_8edba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8edba_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_8edba_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_8edba_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_8edba_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_8edba_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_8edba_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_8edba_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_8edba_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8edba_level0_row0" class="row_heading level0 row0" >AveragePrice</th>
#       <td id="T_8edba_row0_col0" class="data row0 col0" >18249.000000</td>
#       <td id="T_8edba_row0_col1" class="data row0 col1" >1.405978</td>
#       <td id="T_8edba_row0_col2" class="data row0 col2" >0.402677</td>
#       <td id="T_8edba_row0_col3" class="data row0 col3" >0.440000</td>
#       <td id="T_8edba_row0_col4" class="data row0 col4" >1.100000</td>
#       <td id="T_8edba_row0_col5" class="data row0 col5" >1.370000</td>
#       <td id="T_8edba_row0_col6" class="data row0 col6" >1.660000</td>
#       <td id="T_8edba_row0_col7" class="data row0 col7" >3.250000</td>
#     </tr>
#     <tr>
#       <th id="T_8edba_level0_row1" class="row_heading level0 row1" >Total Volume</th>
#       <td id="T_8edba_row1_col0" class="data row1 col0" >18249.000000</td>
#       <td id="T_8edba_row1_col1" class="data row1 col1" >850644.013009</td>
#       <td id="T_8edba_row1_col2" class="data row1 col2" >3453545.355399</td>
#       <td id="T_8edba_row1_col3" class="data row1 col3" >84.560000</td>
#       <td id="T_8edba_row1_col4" class="data row1 col4" >10838.580000</td>
#       <td id="T_8edba_row1_col5" class="data row1 col5" >107376.760000</td>
#       <td id="T_8edba_row1_col6" class="data row1 col6" >432962.290000</td>
#       <td id="T_8edba_row1_col7" class="data row1 col7" >62505646.520000</td>
#     </tr>
#     <tr>
#       <th id="T_8edba_level0_row2" class="row_heading level0 row2" >4046</th>
#       <td id="T_8edba_row2_col0" class="data row2 col0" >18249.000000</td>
#       <td id="T_8edba_row2_col1" class="data row2 col1" >293008.424531</td>
#       <td id="T_8edba_row2_col2" class="data row2 col2" >1264989.081763</td>
#       <td id="T_8edba_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_8edba_row2_col4" class="data row2 col4" >854.070000</td>
#       <td id="T_8edba_row2_col5" class="data row2 col5" >8645.300000</td>
#       <td id="T_8edba_row2_col6" class="data row2 col6" >111020.200000</td>
#       <td id="T_8edba_row2_col7" class="data row2 col7" >22743616.170000</td>
#     </tr>
#     <tr>
#       <th id="T_8edba_level0_row3" class="row_heading level0 row3" >4225</th>
#       <td id="T_8edba_row3_col0" class="data row3 col0" >18249.000000</td>
#       <td id="T_8edba_row3_col1" class="data row3 col1" >295154.568356</td>
#       <td id="T_8edba_row3_col2" class="data row3 col2" >1204120.401135</td>
#       <td id="T_8edba_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_8edba_row3_col4" class="data row3 col4" >3008.780000</td>
#       <td id="T_8edba_row3_col5" class="data row3 col5" >29061.020000</td>
#       <td id="T_8edba_row3_col6" class="data row3 col6" >150206.860000</td>
#       <td id="T_8edba_row3_col7" class="data row3 col7" >20470572.610000</td>
#     </tr>
#     <tr>
#       <th id="T_8edba_level0_row4" class="row_heading level0 row4" >4770</th>
#       <td id="T_8edba_row4_col0" class="data row4 col0" >18249.000000</td>
#       <td id="T_8edba_row4_col1" class="data row4 col1" >22839.735993</td>
#       <td id="T_8edba_row4_col2" class="data row4 col2" >107464.068435</td>
#       <td id="T_8edba_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_8edba_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_8edba_row4_col5" class="data row4 col5" >184.990000</td>
#       <td id="T_8edba_row4_col6" class="data row4 col6" >6243.420000</td>
#       <td id="T_8edba_row4_col7" class="data row4 col7" >2546439.110000</td>
#     </tr>
#     <tr>
#       <th id="T_8edba_level0_row5" class="row_heading level0 r

# %% [markdown]
# 오래걸림

# %%
# --- Plot Size ---
fig, axs = plt.subplots(9, 2, figsize = (16, 30))

# --- General Title ---
fig.tight_layout()
fig.subplots_adjust(top = 0.95)
fig.suptitle('Histogram of Continuous Columns', fontweight = 'bold', fontsize = 16, fontfamily = 'sans-serif', 
             color = black_grad[0])

# --- Continuous Variables (Row 1) ---
sns.histplot(data = ds, x = 'AveragePrice', kde = True, ax = axs[0, 0], color = '#004D25')
sns.boxenplot(data = ds, x = 'AveragePrice', ax = axs[0, 1], color = '#004D25')

# --- Continuous Variables (Row 2) ---
sns.histplot(data = ds, x = 'Total Volume', kde = True, ax = axs[1, 0], color = '#EDDE30')
sns.boxenplot(data = ds, x = 'Total Volume', ax = axs[1, 1], color = '#EDDE30')

# --- Continuous Variables (Row 3) ---
sns.histplot(data = ds, x='4046', kde = True, ax = axs[2, 0], color = '#48BF53')
sns.boxenplot(data = ds, x = '4046', ax = axs[2, 1], color = '#48BF53')

# --- Continuous Variables (Row 4) ---
sns.histplot(data = ds, x = '4225', kde = True, ax = axs[3, 0], color = '#837A0B')
sns.boxenplot(data = ds, x = '4225', ax = axs[3, 1], color = '#837A0B')

# --- Continuous Variables (Row 5) ---
sns.histplot(data = ds, x = '4770', kde = True, ax = axs[4, 0], color = '#664228')
sns.boxenplot(data = ds, x = '4770', ax = axs[4, 1], color = '#664228')

# --- Continuous Variables (Row 6) ---
sns.histplot(data = ds, x = 'Total Bags', kde = True, ax = axs[5, 0], color = '#A4E637')
sns.boxenplot(data = ds, x = 'Total Bags', ax = axs[5, 1], color = '#A4E637')

# --- Continuous Variables (Row 7) ---
sns.histplot(data = ds, x = 'Small Bags', kde = True, ax = axs[6, 0], color = '#BF865D')
sns.boxenplot(data = ds, x = 'Small Bags', ax = axs[6, 1], color = '#BF865D')

# --- Continuous Variables (Row 8) ---
sns.histplot(data = ds, x = 'Large Bags', kde = True, ax = axs[7, 0], color = '#D98000')
sns.boxenplot(data = ds, x = 'Large Bags', ax = axs[7, 1], color = '#D98000')

# --- Continuous Variables (Row 9) ---
sns.histplot(data = ds, x = 'XLarge Bags', kde = True, ax = axs[8, 0], color = '#557F0F')
sns.boxenplot(data = ds, x = 'XLarge Bags', ax = axs[8, 1], color = '#557F0F');

# %%
# --- Skewness of Continuous Variables ---
print('\033[92m\033[1m'+'.: Continuous Columns Skewness :.'+'\033[0m')
print('\033[92m*' * 34+'\033[0m')
ds[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 
    'XLarge Bags']].skew(axis = 0, skipna = True)
# Out:
# .: Continuous Columns Skewness :.
# **********************************
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# dtype: float64

# %%
# --- Kurtoisis of Continuous Variables ---
print('\033[92m\033[1m'+'.: Continuous Columns Kurtosis :.'+'\033[0m')
print('\033[92m*' * 34+'\033[0m')
ds[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 
    'XLarge Bags']].kurt(axis = 0, skipna = True)
# Out:
# .: Continuous Columns Kurtosis :.
# **********************************
# AveragePrice      0.325196
# Total Volume     92.104458
# 4046             86.809113
# 4225             91.949022
# 4770            132.563441
# Total Bags      112.272156
# Small Bags      107.012885
# Large Bags      117.999481
# XLarge Bags     233.602612
# dtype: float64

# %%
# --- Create New Dataframes based on Type ---
eda0 = ds[['region', 'Total Volume']][ds.type == 'conventional']
eda0 = eda0[eda0['region'] != 'TotalUS']
eda0 = eda0.groupby(['region']).aggregate({'Total Volume': np.mean}).sort_values(by = 'Total Volume',
                                                                                 ascending = False).iloc[:5]

eda1 = ds[['region', 'Total Volume']][ds.type == 'organic']
eda1 = eda1[eda1['region'] != 'TotalUS']
eda1 = eda1.groupby(['region']).aggregate({'Total Volume': np.mean}).sort_values(by = 'Total Volume', 
                                                                                 ascending = False).iloc[:5]

# --- General Settings of Bar Charts ---
fig, ax = plt.subplots(1, 2, figsize = (20, 6))
fig.suptitle('Top 5 Regions w/ The Most Sales', fontweight = 'heavy', fontsize = 16, fontfamily = 'sans-serif',
             color = black_grad[0])

# --- Bar Chart Left ---
plt.subplot(1, 2, 1)
plt.title('Conventional Avocado', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
bar_left = sns.barplot(x='Total Volume', y = eda0.index, data = eda0, palette = black_grad, edgecolor = black_grad[2], 
                       alpha = 0.85)
bar_left.patches[0].set_facecolor(olive_grad[0])
bar_left.patches[1].set_facecolor(olive_grad[1])
bar_left.patches[2].set_facecolor(olive_grad[2])
plt.xlabel('Total Volume', fontweight='bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0)
plt.grid(axis = 'x', alpha = 0.4)
plt.ticklabel_format(style = 'plain', axis = 'x')

# --- Bar Chart Right ---
plt.subplot(1, 2, 2)
plt.title('Organic Avocado', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
bar_right = sns.barplot(x='Total Volume', y = eda1.index, data = eda1, palette = black_grad, edgecolor = black_grad[2],
                        alpha = 0.85)
bar_right.patches[0].set_facecolor(yellow_grad[1])
bar_right.patches[1].set_facecolor(yellow_grad[2])
bar_right.patches[2].set_facecolor(yellow_grad[3])
plt.xlabel('Total Volume', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0)
plt.grid(axis = 'x', alpha = 0.4)
plt.ticklabel_format(style = 'plain', axis = 'x')
plt.show()

# %%
# --- Create New Dataframes based on Type ---
eda2 = ds[['region', 'AveragePrice']][ds.type == 'conventional']
eda2 = eda2.groupby(['region']).aggregate({'AveragePrice': np.mean}).sort_values(by = 'AveragePrice', 
                                                                                 ascending = False).iloc[:5]

eda3 = ds[['region', 'AveragePrice']][ds.type == 'organic']
eda3 = eda3.groupby(['region']).aggregate({'AveragePrice': np.mean}).sort_values(by = 'AveragePrice',
                                                                                 ascending = False).iloc[:5]

# --- General Settings of Bar Charts ---
fig, ax = plt.subplots(1, 2, figsize = (20, 6))
fig.suptitle('Top 5 Regions w/ Highest Avocado Price', fontweight = 'heavy', fontsize = 16, fontfamily = 'sans-serif', 
             color = black_grad[0])

# --- Bar Chart Left ---
plt.subplot(1, 2, 1)
plt.title('Conventional Avocado', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
bar_left = sns.barplot(y = 'AveragePrice', x = eda2.index, data = eda2, palette = black_grad, edgecolor = black_grad[2],
                       alpha = 0.85)
bar_left.patches[0].set_facecolor(olive_grad[0])
bar_left.patches[1].set_facecolor(olive_grad[1])
bar_left.patches[2].set_facecolor(olive_grad[2])
plt.xlabel('Price', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.ticklabel_format(style = 'plain', axis = 'y')

# --- Bar Chart Right ---
plt.subplot(1, 2, 2)
plt.title('Organic Avocado', fontweight = 'bold', fontsize = '12', fontfamily = 'sans-serif', color = black_grad[1])
bar_right = sns.barplot(y='AveragePrice', x = eda3.index, data = eda3, palette = black_grad, edgecolor = black_grad[2],
                        alpha = 0.85)
bar_right.patches[0].set_facecolor(yellow_grad[1])
bar_right.patches[1].set_facecolor(yellow_grad[2])
bar_right.patches[2].set_facecolor(yellow_grad[3])
plt.xlabel('Price', fontweight='bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show();

# %%
# --- Creating New Data Frame ---
eda30 = ds[['type', '4046', '4225', '4770']]
eda30 = eda30.groupby(['type']).aggregate({'4046': np.mean, '4225': np.mean, '4770': np.mean})

# --- Stacked Bar Chart ---
eda30.plot(kind='bar', stacked = True, color = color_mix[-4:-1], alpha = 0.85)
plt.title('Comparison of Avocado PLU Sold', fontweight = 'bold', fontsize = '12', fontfamily = 'sans-serif', 
          color = black_grad[1])
plt.xlabel('Type', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Avg. Total', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.legend(labels = ['PLU 4046','PLU 4225', 'PLU 4770'], title = '$\\bf{Type}$', fontsize = '8', title_fontsize = '9',
           loc = 'upper right', frameon = True)
plt.xticks(rotation = 0)
plt.ticklabel_format(style = 'plain', axis = 'y');

# %%
# --- Creating New Data Frame ---
eda31 = ds[['type', 'Small Bags', 'Large Bags', 'XLarge Bags']]
eda31 = eda31.groupby(['type']).aggregate({'Small Bags': np.mean, 'Large Bags': np.mean, 'XLarge Bags': np.mean})

# --- Stacked Bar Chart ---
eda31.plot(kind = 'bar', stacked = True, color = color_mix[3:0:-1], alpha = 0.85)
plt.title('Bag Size Comparison', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
plt.xlabel('Type', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Avg. Total', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.legend(labels = ['Small Bags','Large Bags', 'XLarge Bags'], title = '$\\bf{Type}$', fontsize = 8, title_fontsize = 9,
           loc = 'upper right', frameon = True)
plt.xticks(rotation = 0)
plt.ticklabel_format(style = 'plain', axis = 'y');

# %%
# --- Creating Box Plot based on Type ---
fig, ax = plt.subplots()
fig.set_size_inches(17, 7)
plt.title('Average Price Distribution based on Types from 2015-2018', fontweight='bold', fontsize = 14, 
          fontfamily = 'sans-serif', color = black_grad[0])
sns.boxplot(x = 'year', y = 'AveragePrice', hue = 'type', data = ds, ax = ax, palette = color_mix[1:3], 
            boxprops = dict(alpha = 0.9), linewidth = 1.5)
plt.xlabel('Year', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Average Price', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)
plt.legend(title = '$\\bf{Type}$', fontsize = 8, title_fontsize = 9, loc = 'upper right', frameon = True)
plt.grid(axis = 'y', alpha = 0.4)
plt.show()

# %%
# --- Seperating Total Volume & Total Bags based on Type ---
x0 = ds.xs('Total Volume', axis = 1)[ds.type == 'conventional']
x1 = ds.xs('Total Volume', axis = 1)[ds.type == 'organic']
y0 = ds.xs('Total Bags', axis = 1)[ds.type == 'conventional']
y1 = ds.xs('Total Bags', axis = 1)[ds.type == 'organic']

# --- Creating Scatter Plot ---
plt.figure(figsize = (8, 7))
plt.title('Scatter Plot between Avg. Price and Total Volume', fontweight = 'bold', fontsize = 14, 
          fontfamily = 'sans-serif', color = black_grad[0])
plt.scatter(x = x0, y = y0, c = color_mix[1], alpha = 0.6, linewidths = 1)
plt.scatter(x = x1, y = y1, c = color_mix[2], alpha = 0.6, linewidths = 1)
plt.legend(['Conventional', 'Organic'], title = '$\\bf{Type}$', fontsize = 7, title_fontsize = 8, loc = 'upper left',
           frameon = True)
plt.xlabel('Total Volume', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Total Bags', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ticklabel_format(style = 'plain', axis = 'both')
plt.grid(axis = 'both', alpha = 0.5, lw = 0.5)
plt.show()

# %%
# --- Calculating Mean of `Total Volume` grouped by Type and Date ---
dseda8 = ds[['Date', 'Total Volume', 'type']]
dseda8['Date'] = pd.DatetimeIndex(dseda8['Date'])
dseda8['Date'] = dseda8['Date'].apply(lambda x: x.strftime('%Y-%m'))
group8 = dseda8.groupby(['Date', 'type'])
mnth_avg8 = group8.aggregate({'Total Volume': np.mean})

# --- Creating Time Series Plot of Avg. Price ---
plt.figure(figsize = (10, 6))
plt.title('Avg. Avocado Sold based on Type from 2015-2018', fontweight = 'bold', fontsize = 14,
          fontfamily = 'sans-serif', color = black_grad[0])
sns.lineplot(data = mnth_avg8, x = 'Date', y = 'Total Volume', hue = 'type', style = 'type', markers = ['o', 'o'],
             palette = color_mix[0:2], alpha = 0.85)
plt.xlabel('Date (Year-Month)', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ylabel('Avg. Sold', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = '90', fontsize = 7)
plt.yticks(rotation = '45', fontsize = 7)
plt.grid(axis='y', alpha = 0.5, lw = 0.6)
plt.grid(axis='x', alpha = 0)
plt.legend(labels = ['Conventional', 'Organic'], title = '$\\bf{Type}$', fontsize = 7, title_fontsize = 8, frameon=True);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[186], line 17
#      13              palette = color_mix[0:2], alpha = 0.85)
#      14 plt.xlabel('Date (Year-Month)', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
#      15 plt.ylabel('Avg. Sold', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
#      16 plt.ticklabel_format(style='plain', axis='y')
# ---> 17 plt.xticks(rotation = '90', fontsize = 7)
#      18 plt.yticks(rotation = '45', fontsize = 7)
#      19 plt.grid(axis='y', alpha = 0.5, lw = 0.6)
#      20 plt.grid(axis='x', alpha = 0)
#
# File ~\anaconda3\envs\pycaret_env\Lib\site-packages\matplotlib\pyplot.py:1891, in xticks(ticks, labels, minor, **kwargs)
#    1889     labels = ax.get_xticklabels(minor=minor)
#    1890     for l in labels:
# -> 1891         l._internal_update(kwargs)
#    1892 else:
#    1893     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\envs\pycaret_env\Lib\site-packages\matplotlib\artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~\anaconda3\envs\pycaret_env\Lib\site-packages\matplotlib\artist.py:1199, in Artist._update_props(self, props, errfmt)
#    1196             if not callable(func):
#    1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
# -> 1199             ret.append(func(v))
#    1200 if ret:
#    1201     self.pchanged()
#
# File ~\anaconda3\envs\pycaret_env\Lib\site-packages\matplotlib\text.py:1234, in Text.set_rotation(self, s)
#    1232     self._rotation = 90.
#    1233 else:
# -> 1234     raise ValueError("rotation must be 'vertical', 'horizontal' or "
#    1235                      f"a number, not {s}")
#    1236 self.stale = True
#
# ValueError: rotation must be 'vertical', 'horizontal' or a number, not 90

# %%
# --- Calculating Mean of `AveragePrice` grouped by Type and Date ---
dseda9 = ds[['Date', 'AveragePrice', 'type']]
dseda9['Date'] = pd.DatetimeIndex(dseda9['Date'])
dseda9['Date'] = dseda9['Date'].apply(lambda x: x.strftime('%Y-%m'))
group9 = dseda9.groupby(['Date', 'type'])
mnth_avg9 = group9.aggregate({'AveragePrice': np.mean})

# --- Creating Time Series Plot of Avg. Price ---
plt.figure(figsize = (10, 6))
plt.title('Avg. Price of Avocado Type from 2015-2018', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif',
          color = black_grad[0])
sns.lineplot(data = mnth_avg9, x = 'Date', y = 'AveragePrice', hue = 'type', style = 'type', markers = ['o', 'o'],
             palette = 'YlOrBr_r', alpha = 0.85)
plt.xlabel('Date (Year-Month)', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ylabel('Average Price', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.xticks(rotation = 90, fontsize = 7)
plt.yticks(fontsize = 7)
plt.grid(axis = 'y', alpha = 0.5, lw = 0.6)
plt.grid(axis = 'x', alpha = 0)
plt.legend(labels = ['Conventional', 'Organic'], title = '$\\bf{Type}$', fontsize = 7, title_fontsize = 8,
           loc = 'upper left', frameon = True);

# %%
# --- Correlation Map (Heatmap) ---
plt.figure(figsize = (12, 8))
# numeric_only=True 추가 및 cmap 이름에 따옴표 추가
sns.heatmap(ds.corr(numeric_only=True), annot=True, cmap='Greens_r', linewidths=0.1)
plt.title('Correlation Map of Numerical Variables', fontsize = 14, fontweight = 'bold', fontfamily = 'sans-serif',
          color = black_grad[0]);

# %%
# 1. Date 컬럼을 날짜 형식으로 변환
ds['Date'] = pd.to_datetime(ds['Date'])

# 2. Date에서 월(month) 정보를 추출하여 새 컬럼 생성
ds['month'] = ds['Date'].dt.month

# 3. 이제 다시 setup 실행
avc = setup(data = ds, target = 'AveragePrice', train_size = 0.8, 
            categorical_features = ['type', 'year', 'region', 'month'], 
            normalize = True, normalize_method = 'robust', 
            session_id = 123)
# Out:
# <style type="text/css">
# #T_83100_row10_col1, #T_83100_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_83100">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83100_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_83100_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83100_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83100_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_83100_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83100_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_83100_row1_col1" class="data row1 col1" >AveragePrice</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83100_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_83100_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83100_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_83100_row3_col1" class="data row3 col1" >(18249, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83100_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_83100_row4_col1" class="data row4 col1" >(18249, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83100_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_83100_row5_col1" class="data row5 col1" >(14599, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83100_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_83100_row6_col1" class="data row6 col1" >(3650, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83100_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_83100_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83100_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_83100_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83100_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_83100_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_83100_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_83100_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_83100_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_83100_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_83100_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_83100_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_83100_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_83100_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_83100_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_83100_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_83100_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_83100_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_83100_row16_col0" class="data row16 col0" >Normalize</td>
#       <td id="T_83100_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_83100_row17_col0" class="data row17 col0" >Normalize method</td>
#       <td id="T_83100_row17_col1" class="data row17 col1" >robust</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_83100_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_83100_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_83100_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_83100_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_83100_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_83100_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_83100_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_83100_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_83100_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_83100_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_83100_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_83100_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_83100_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_83100_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_83100_row24_col1" class="data row24 col1" >b0ae</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- List PyCaret Regression Models ---
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# lightgbm    Light Gradient Boosting Machine
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
# --- Comparing All Models ---
best_models = compare_models(sort='R2')
# Out:
# <style type="text/css">
# #T_ce6b9 th {
#   text-align: left;
# }
# #T_ce6b9_row0_col0, #T_ce6b9_row1_col0, #T_ce6b9_row1_col1, #T_ce6b9_row1_col2, #T_ce6b9_row1_col3, #T_ce6b9_row1_col4, #T_ce6b9_row1_col5, #T_ce6b9_row1_col6, #T_ce6b9_row2_col0, #T_ce6b9_row2_col1, #T_ce6b9_row2_col2, #T_ce6b9_row2_col3, #T_ce6b9_row2_col4, #T_ce6b9_row2_col5, #T_ce6b9_row2_col6, #T_ce6b9_row3_col0, #T_ce6b9_row3_col1, #T_ce6b9_row3_col2, #T_ce6b9_row3_col3, #T_ce6b9_row3_col4, #T_ce6b9_row3_col5, #T_ce6b9_row3_col6, #T_ce6b9_row4_col0, #T_ce6b9_row4_col1, #T_ce6b9_row4_col2, #T_ce6b9_row4_col3, #T_ce6b9_row4_col4, #T_ce6b9_row4_col5, #T_ce6b9_row4_col6, #T_ce6b9_row5_col0, #T_ce6b9_row5_col1, #T_ce6b9_row5_col2, #T_ce6b9_row5_col3, #T_ce6b9_row5_col4, #T_ce6b9_row5_col5, #T_ce6b9_row5_col6, #T_ce6b9_row6_col0, #T_ce6b9_row6_col1, #T_ce6b9_row6_col2, #T_ce6b9_row6_col3, #T_ce6b9_row6_col4, #T_ce6b9_row6_col5, #T_ce6b9_row6_col6, #T_ce6b9_row7_col0, #T_ce6b9_row7_col1, #T_ce6b9_row7_col2, #T_ce6b9_row7_col3, #T_ce6b9_row7_col4, #T_ce6b9_row7_col5, #T_ce6b9_row7_col6, #T_ce6b9_row8_col0, #T_ce6b9_row8_col1, #T_ce6b9_row8_col2, #T_ce6b9_row8_col3, #T_ce6b9_row8_col4, #T_ce6b9_row8_col5, #T_ce6b9_row8_col6, #T_ce6b9_row9_col0, #T_ce6b9_row9_col1, #T_ce6b9_row9_col2, #T_ce6b9_row9_col3, #T_ce6b9_row9_col4, #T_ce6b9_row9_col5, #T_ce6b9_row9_col6, #T_ce6b9_row10_col0, #T_ce6b9_row10_col1, #T_ce6b9_row10_col2, #T_ce6b9_row10_col3, #T_ce6b9_row10_col4, #T_ce6b9_row10_col5, #T_ce6b9_row10_col6, #T_ce6b9_row11_col0, #T_ce6b9_row11_col1, #T_ce6b9_row11_col2, #T_ce6b9_row11_col3, #T_ce6b9_row11_col4, #T_ce6b9_row11_col5, #T_ce6b9_row11_col6, #T_ce6b9_row12_col0, #T_ce6b9_row12_col1, #T_ce6b9_row12_col2, #T_ce6b9_row12_col3, #T_ce6b9_row12_col4, #T_ce6b9_row12_col5, #T_ce6b9_row12_col6, #T_ce6b9_row13_col0, #T_ce6b9_row13_col1, #T_ce6b9_row13_col2, #T_ce6b9_row13_col3, #T_ce6b9_row13_col4, #T_ce6b9_row13_col5, #T_ce6b9_row13_col6, #T_ce6b9_row14_col0, #T_ce6b9_row14_col1, #T_ce6b9_row14_col2, #T_ce6b9_row14_col3, #T_ce6b9_row14_col4, #T_ce6b9_row14_col5, #T_ce6b9_row14_col6, #T_ce6b9_row15_col0, #T_ce6b9_row15_col1, #T_ce6b9_row15_col2, #T_ce6b9_row15_col3, #T_ce6b9_row15_col4, #T_ce6b9_row15_col5, #T_ce6b9_row15_col6, #T_ce6b9_row16_col0, #T_ce6b9_row16_col1, #T_ce6b9_row16_col2, #T_ce6b9_row16_col3, #T_ce6b9_row16_col4, #T_ce6b9_row16_col5, #T_ce6b9_row16_col6, #T_ce6b9_row17_col0, #T_ce6b9_row17_col1, #T_ce6b9_row17_col2, #T_ce6b9_row17_col3, #T_ce6b9_row17_col4, #T_ce6b9_row17_col5, #T_ce6b9_row17_col6 {
#   text-align: left;
# }
# #T_ce6b9_row0_col1, #T_ce6b9_row0_col2, #T_ce6b9_row0_col3, #T_ce6b9_row0_col4, #T_ce6b9_row0_col5, #T_ce6b9_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ce6b9_row0_col7, #T_ce6b9_row1_col7, #T_ce6b9_row2_col7, #T_ce6b9_row3_col7, #T_ce6b9_row4_col7, #T_ce6b9_row5_col7, #T_ce6b9_row6_col7, #T_ce6b9_row7_col7, #T_ce6b9_row8_col7, #T_ce6b9_row9_col7, #T_ce6b9_row10_col7, #T_ce6b9_row11_col7, #T_ce6b9_row12_col7, #T_ce6b9_row13_col7, #T_ce6b9_row14_col7, #T_ce6b9_row16_col7, #T_ce6b9_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ce6b9_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ce6b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce6b9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ce6b9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ce6b9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ce6b9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ce6b9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ce6b9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ce6b9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ce6b9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce6b9_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_ce6b9_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_ce6b9_row0_col1" class="data row0 col1" >0.0739</td>
#       <td id="T_ce6b9_row0_col2" class="data row0 col2" >0.0117</td>
#       <td id="T_ce6b9_row0_col3" class="data row0 col3" >0.1081</td>
#       <td id="T_ce6b9_row0_col4" class="data row0 col4" >0.9278</td>
#       <td id="T_ce6b9_row0_col5" class="data row0 col5" >0.0434</td>
#       <td id="T_ce6b9_row0_col6" class="data row0 col6" >0.0545</td>
#       <td id="T_ce6b9_row0_col7" class="data row0 col7" >2.2140</td>
#     </tr>
#     <tr>
#       <th id="T_ce6b9_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_ce6b9_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_ce6b9_row1_col1" class="data row1 col1" >0.0801</td>
#       <td id="T_ce6b9_row1_col2" class="data row1 col2" >0.0132</td>
#       <td id="T_ce6b9_row1_col3" class="data row1 col3" >0.1146</td>
#       <td id="T_ce6b9_row1_col4" class="data row1 col4" >0.9187</td>
#       <td id="T_ce6b9_row1_col5" class="data row1 col5" >0.0460</td>
#       <td id="T_ce6b9_row1_col6" class="data row1 col6" >0.0592</td>
#       <td id="T_ce6b9_row1_col7" class="data row1 col7" >5.1740</td>
#     </tr>
#     <tr>
#       <th id="T_ce6b9_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_ce6b9_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ce6b9_row2_col1" class="data row2 col1" >0.0986</td>
#       <td id="T_ce6b9_row2_col2" class="data row2 col2" >0.0174</td>
#       <td id="T_ce6b9_row2_col3" class="data row2 col3" >0.1320</td>
#       <td id="T_ce6b9_row2_col4" class="data row2 col4" >0.8922</td>
#       <td id="T_ce6b9_row2_col5" class="data row2 col5" >0.0535</td>
#       <td id="T_ce6b9_row2_col6" class="data row2 col6" >0.0731</td>
#       <td id="T_ce6b9_row2_col7" class="data row2 col7" >0.8790</td>
#     </tr>
#     <tr>
#       <th id="T_ce6b9_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_ce6b9_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_ce6b9_row3_col1" class="data row3 col1" >0.1115</td>
#       <td id="T_ce6b9_row3_col2" class="data row3 col2" >0.0284</td>
#       <td id="T_ce6b9_row3_col3" class="data row3 col3" >0.1685</td>
#       <td id="T_ce6b9_row3_col4" class="data row3 col4" >0.8241</td>
#       <td id="T_ce6b9_row3_col5" class="data row3 col5" >0.0673</td>
#       <td id="T_ce6b9_row3_col6" class="data row3 col6" >0.0813</td>
#       <td id="T_ce6b9_row3_col7" class="data row3 col7" >0.1800</td>
#     </tr>
#     <tr>
#       <th id="T_ce6b9_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_ce6b9_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ce6b9_row4_col1" class="data row4 col1" >0.1380</td>
#       <td id="T_ce6b9_row4_col2" class="data row4 col2" >0.0341</td>
#       <td id="T_ce6b9_row4_col3" class="data row4 col3" >0.1846</td>
#       <td id="T_ce6b9_row4_col4" class="data row4 col4" >0.7894</td>
#       <td id="T_ce6b9_row4_col5" class="data row4 col5" >0.0740</td>
#       <td id="T_ce6b9_row4_col6" class="data row4 col6" >0.1024</td>
#       <td id="T_ce6b9_row4_col7" class="data row4 col7" >1.7020</td>
#     </tr>
#     <tr>
#       <th id="T_ce6b9_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_ce6b9_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_ce6b9_row5_col1" class="data row5 col1" >0.1563</td>
#       <td id="T_ce6b9_row5_col2" class="data row5 col2" >0.0466</td>
#       <td id="T_ce6b9_row5_col3" class="data row5 col3" >0.2158</td>
#       <td id="T_ce6b9_row5_col4" class="data row5 col4" >0.7122</td>
#       <td id="T_ce6b9_row5_col5" class="data row5 col5" >0.0862</td>
#       <td id="T_ce6b9_row5_col6" class="data row5 col6" >0.1153</td>
#       <td id="T_ce6b9_row5_col7" class="data row5 col7" >0.1800</td>
#     </tr>
#     <tr>
#       <th id="T_ce6b9_level

# %%
# --- Plot the Residual of Best Model (et) ---
plot_model(best_models)

# %%
# --- Plot Error Prediction for Best Model ---
plot_model(best_models, plot = 'error')

# %%
# --- Plot Feature Importance for Best Model ---
plot_model(best_models, plot = 'feature')

# %%
# --- Tuning Best Model ---
tuned_best = tune_model(best_models)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   20:08:46
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .      Extra Trees Regressor
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# --- Plot the Residual of Tuned Best Model ---
plot_model(tuned_best)

# %%
# --- Plot Error Prediction for Tuned Best Model ---
plot_model(tuned_best, plot = 'error')

# %%
# --- Plot Feature Importance for Tuned Best Model ---
plot_model(tuned_best, plot = 'feature')

# %%
# --- Create RFR Model ---
rf = create_model('rf')

# %%
# --- Plot the Residual of RFR Model ---
plot_model(rf)

# %%
# --- Plot Error Prediction for RFR Model ---
plot_model(rf, plot = 'error')

# %%
# --- Plot Feature Importance for RFR Model --
plot_model(rf, plot = 'feature')

# %%
# --- Tuning RFR Model ---
tune_rf = tune_model(rf)

# %%
# --- Plot the Residual of RFR Model ---
plot_model(tune_rf)

# %%
# --- Plot Error Prediction for Tuned RFR Model ---
plot_model(tune_rf, plot = 'error')

# %%
# --- Plot Feature Importance for Tuned RFR Model ---
plot_model(tune_rf, plot = 'feature')

# %%
# --- Create Light GBM ---
lgbm = create_model('lightgbm')

# %%
# --- Plot the Residual of Light GBM ---
plot_model(lgbm)

# %%
# --- Plot Error Prediction for Light GBM ---
plot_model(lgbm, plot = 'error')

# %%
# --- Plot Feature Importance for Light GBM --
plot_model(lgbm, plot = 'feature')

# %%
# --- Tuning Light Gradient Boost ---
tune_lgbm = tune_model(lgbm)

# %%
# --- Plot the Residual of Tuned Light Gradient Boost ---
plot_model(tune_lgbm)

# %%
# --- Plot Error Prediction for Tuned Light Gradient Boost ---
plot_model(tune_lgbm, plot = 'error')

# %%
# --- Plot Feature Importance for Tuned Light Gradient Boost --
plot_model(tune_lgbm, plot = 'feature')

# %%
# --- Prediction using Best Model ---
predict_model(best_models)

# %%
# --- Prediction using RFR Model ---
predict_model(rf)

# %%
# --- Prediction using Light Gradient Boosting Model ---
predict_model(lgbm)

# %%
# --- Finalize Best Model ---
final_best = finalize_model(best_models)

# --- Final Best Model Parameters for Deployment ---
plot_model(best_models, plot='parameter')

# %%
# --- Prediction using Final Model ---
predict_model(final_best)

# %%
# --- Save Final Model into Pickle File ---
save_model(final_best,'Final_Best_Model_caesarmario_06May2022')
